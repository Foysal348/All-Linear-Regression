# %% [markdown]
# <a href="https://colab.research.google.com/github/Foysal348/Assignment/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h4>1.Simple Linear Regression</h4>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


x=np.array([1,2,3,4,5]).reshape(-1,1)
y=np.array([2,4,5,4,5])

#Model Selection
model=LinearRegression()
#Model Fit
model.fit(x,y)
#Prediction y(cap)
y_pred=model.predict(x)

#Visualization
plt.scatter(x,y,color='r',label='Actual Data')
plt.plot(x,y_pred,color='g',label='Line')
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.title("Simple Linear Regression")
plt.legend()
plt.grid()
plt.show()

 #display Coefficients
print("Coefficient(slope):",model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficient(slope): [0.6]
# Intercept: 2.2
